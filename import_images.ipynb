# %%
data = os.getcwd()
print(data)
# Out:
# c:\Users\benoi\OneDrive\Documenten\Vakken 3ICT Sem1\Bachelorproef\BP_HousePricePrediction

# %%
from pathlib import Path
from shutil import rmtree as delete
from urllib.request import urlretrieve as download
from gazpacho import get, Soup
import re
import pandas as pd
import numpy as np
import os
import urllib.request as urlopen
import ssl

#add certificate workaround to scrape immoweb images (Python venv has no certificates and can't verify ssl) 
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    # Legacy Python that doesn't verify HTTPS certificates by default
    pass
else:
    # Handle target environment that doesn't support HTTPS verification
    ssl._create_default_https_context = _create_unverified_https_context
context = ssl._create_unverified_context()


#import data
#web-scraper-order	web-scraper-start-url	links	links-href	Prijs	Slaapkamers	Bewoonbare_ruimte	Grond	Bouwjaar	Staat_gebouw	Badkamers	Energieklasse	Postcode	Image_1-src	Image_2-src

colnames = ['Web-scraper-order', 'Web-scraper-start-url', 'Type', 'Links-href', 'Prijs','Slaapkamers','Bewoonbare_ruimte','Grondoppevervlak','Bouwjaar','Conditie','Badkamers','Energieklasse','Postcode','Image1','Image2']
df = pd.read_csv('./immoweb_listings.csv',names=colnames, sep=';',skiprows=1)

#iterate over every row of the data and download the jpg file
i = 0
for url in df['Image2']:
    print(url)
    i+=1
    urlopen.urlretrieve(url, f"./images/pand_{i}_2.jpg")
    


df.shape
# Out:
# https://static.immoweb.be/photos/0/9/8/9/9/6/5/2/M_9899652_2.jpg?cache=20220508082911
# https://static.immoweb.be/photos/0/9/8/8/8/8/9/5/M_9888895_2.jpg?cache=20220503032415
# https://static.immoweb.be/photos/0/9/9/0/0/5/8/3/M_9900583_2.jpg?cache=20220509095350
# https://static.immoweb.be/photos/0/9/6/0/1/0/8/8/M_9601088_2.jpg?cache=20211104023016
# https://media-resize.immowebstatic.be/classifieds/2b660022-eea9-4ff8-8f47-ae3da4452e3e/300x300/39cd87b72189bc01a6537213c8afd830.jpg?cache=20220510190301
# https://static.immoweb.be/photos/0/9/8/8/8/8/1/2/M_9888812_2.jpg?cache=20220503024844
# https://static.immoweb.be/photos/0/9/9/0/1/7/9/4/M_9901794_2.jpg?cache=20220509201401
# https://media-resize.immowebstatic.be/classifieds/3c29d0de-c34c-4943-9c22-4750a957c9f9/300x300/ab43f58562f19ae7d056cc384dfbbbb0.jpg?cache=20220509190309
# https://media-resize.immowebstatic.be/classifieds/5b54b35e-227e-4a24-b4c0-2583a655e68b/300x300/e42c1f9faa6c11ea84c6d4d92fbd135c.jpg?cache=20220508180049
# ...
